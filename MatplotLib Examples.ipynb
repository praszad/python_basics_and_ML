# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# plt.plot(); Adding Semicollan will removes the empty Array in the start
plt.plot();

# %%
fig, ax = plt.subplots()
x = [1,2,3,4]
y = [10,20,30,40]
ax.plot(x,y)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
fig ,ax = plt.subplots()
x = np.linspace(0,10,100)
ax.plot(x,x**2);
ax.set(title="Sample Chart",xlabel="-Axis",ylabel="Y-Axis")
# Out:
# [Text(0, 0.5, 'Product Name'),
#  Text(0.5, 0, 'Price'),
#  Text(0.5, 1.0, 'Sales Report')]

# %%
fig, ax = plt.subplots()
ax.scatter(x,x);

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
fig, ax = plt.subplots()
barchart_data = {"Alamond":10,"Peanut":8,"Cashew":12}
ax.bar(barchart_data.keys(),barchart_data.values());

# %%
fig , ax = plt.subplots()
ax.barh(list(barchart_data.keys()),(barchart_data.values()))
ax.set(title="Sales Report",xlabel="Price",ylabel="Product Name");

# %%
fig , ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax1.bar(barchart_data.keys(),barchart_data.values());
ax2.scatter(np.random.randn(10),np.random.randn(10));
ax3.plot(x,x);
ax4.hist(np.random.randn(1000));
